# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
plt.plot(
    np.arange(256), 
    np.loadtxt('res.txt')
)
plt.xlabel("Pixel values")
plt.ylabel("Number of pixels")
plt.grid(True)
plt.show()
